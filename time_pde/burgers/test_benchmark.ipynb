# %%
import heat_benchmark 
bm = heat_benchmark.HeatBenchMark(2,0.02,1,tmin = 0, tmax = 3)
X,y = bm.gen_testdata()
import matplotlib.pyplot as plt
plt.scatter(X[:,0],X[:,1],c = y)

plt.figure()
bm = heat_benchmark.HeatBenchMark(2,0.02,1,tmin = 1, tmax = 2)
X,y = bm.gen_testdata()
import matplotlib.pyplot as plt
plt.scatter(X[:,0],X[:,1],c = y)
